# %%
from google.colab import drive
from google.colab import userdata

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/ИТМО/[ITMO] ML subject/Group Project v2/Example-of-solving-a-CV-problem
# Out:
# /content/drive/MyDrive/ИТМО/[ITMO] ML subject/Group Project v2/Example-of-solving-a-CV-problem

# %%
# Out:
# config.yaml  LICENSE          models/           res/       setup.py  yolov5/
# core/        main.py          README_KOR.md     scripts/   trainer/
# easyocr/     main_restapi.py  README.md         send.py    utils/
# image/       MANIFEST.in      requirements.txt  setup.cfg  weights/

# %%
# %ls
# Out:
# dataset/  easy-yolo-ocr/  Preprocess_dataset.ipynb  README.md  train.ipynb

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/ИТМО/[ITMO] ML subject/Group Project v2/Example-of-solving-a-CV-problem

# %%
body = "content/drive/MyDrive/ИТМО/[ITMO] ML subject/Group Project v2/Example-of-solving-a-CV-problem"

# !cp -r {body}/dataset/. {body}/easy-yolo-ocr/yolov5/dataset/
# Out:
# cp: target 'v2/Example-of-solving-a-CV-problem/easy-yolo-ocr/yolov5/dataset/' is not a directory
